# %% [markdown]
# # Matplotlib Examples
#
# This notebook demonstrates various matplotlib plotting capabilities including basic plots, customization, and advanced features.

# %%
1 + 1
# Out:
# 2

# %%
placeholder

# %%
print(42)
# Out:
# 42

# %%
cell_B

# %%
placeholder

# %%
second

# %%
third

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# # This is notebook B [90a2e4b3]
# A hidden content
